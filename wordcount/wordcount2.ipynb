# %%
import re
from collections import Counter

# %%
def cal(filename='wordcount.txt'):
    with open(filename, 'r') as f:
        data = f.read()
    data = data.lower()
    # 替换除了n't这类连字符外的所有非单词字符和数字字符
    datalist = re.split(r'[\s\n]+', data)
    return Counter(datalist).most_common()

# %%
if __name__ == '__main__':
    dic = cal()
    for i  in range(len(dic)):
        print('%15s  ---->   %3s' % (dic[i][0],dic[i][1]))
# Out:
#             the  ---->    25
#             she  ---->    24
#             you  ---->    23
#              to  ---->    23
#              is  ---->    22
#             and  ---->    17
#       empowered  ---->    14
#           woman  ---->    11
#              of  ---->    11
#            love  ---->    10
#              in  ---->    10
#             are  ---->     8
#           knows  ---->     7
#            will  ---->     7
#               a  ---->     7
#             her  ---->     7
#             not  ---->     7
#     understands  ---->     7
#             can  ---->     6
#             how  ---->     6
#              on  ---->     6
#             all  ---->     6
#              it  ---->     5
#            that  ---->     5
#          others  ---->     5
#            your  ---->     4
#            what  ---->     4
#         without  ---->     4
#              or  ---->     4
#              be  ---->     4
#            life  ---->     4
#              at  ---->     4
#          afraid  ---->     4
#           about  ---->     4
#            from  ---->     4
#         someone  ---->     3
#             out  ---->     3
#            live  ---->     3
#              an  ---->     3
#            most  ---->     3
#            when  ---->     3
#            they  ---->     3
#         because  ---->     3
#          happen  ---->     3
#         inspire  ---->     3
#           there  ---->     3
#          people  ---->     3
#         focused  ---->     3
#          change  ---->     3
#           their  ---->     3
#           laugh  ---->     3
#              as  ---->     3
#            with  ---->     3
#           speak  ---->     3
#             for  ---->     2
#          woman.  ---->     2
#            give  ---->     2
#           don’t  ---->     2
#           never  ---->     2
#           loves  ---->     2
#      thoroughly  ---->     2
#        stepping  ---->     2
#           life.  ---->     2
#           learn  ---->     2
#        mistakes  ---->     2
#            part  ---->     2
#       concerned  ---->     2
#           think  ---->     2
#          remain  ---->     2
#           lives  ---->     2
#         change.  ---->     2
#              if  ---->     1
#         looking  ---->     1
#            pour  ---->     1
#             to,  ---->     1
#             let  ---->     1
#              me  ---->     1
#         suggest  ---->     1
#          wants,  ---->     1
#             get  ---->     1
#             it,  ---->     1
#          fully,  ---->     1
#            back  ---->     1
#         needing  ---->     1
#        anyone’s  ---->     1
#        approval  ---->     1
#    recognition.  ---->     1
#      unarguably  ---->     1
#             one  ---->     1
#     magnificent  ---->     1
#          beings  ---->     1
#            ever  ---->     1
#            come  ---->     1
#         contact  ---->     1
#           with.  ---->     1
#            read  ---->     1
#            find  ---->     1
#              10  ---->     1
#          reason  ---->     1
#             why  ---->     1
#          should  ---->     1
#      absolutely  ---->     1
#         embrace  ---->     1
#           women  ---->     1
#           life!  ---->     1
#               .  ---->     1
#              1.  ---->     1
#        returnit  ---->     1
#       difficult  ---->     1
#           have.  ---->     1
#      impossible  ---->     1
#            feel  ---->     1
#       fulfilled  ---->     1
#           can’t  ---->     1
#          return  ---->     1
#     themselves.  ---->     1
#            this  ---->     1
#         herself  ---->     1
#            (not  ---->     1
#    narcissistic  ---->     1
#        manner).  ---->     1
#           turn,  ---->     1
#     appreciates  ---->     1
#             who  ---->     1
#         return.  ---->     1
#            just  ---->     1
#            like  ---->     1
#         deserve  ---->     1
#          loved.  ---->     1
#              2.  ---->     1
#         youwhen  ---->     1
#            puts  ---->     1
#            down  ---->     1
#             end  ---->     1
#           rope,  ---->     1
#             see  ---->     1
#        through.  ---->     1
#          drive,  ---->     1
#      enthusiasm  ---->     1
#             (at  ---->     1
#          times)  ---->     1
#        hopeless  ---->     1
#        optimism  ---->     1
#           carry  ---->     1
#         despite  ---->     1
#       obstacles  ---->     1
#           face.  ---->     1
#              3.  ---->     1
#    failurewhile  ---->     1
#            many  ---->     1
#       terrified  ---->     1
#        failure,  ---->     1
#        failures  ---->     1
#          simply  ---->     1
#          stones  ---->     1
#        unafraid  ---->     1
#            try,  ---->     1
#           fail,  ---->     1
#            shot  ---->     1
#            over  ---->     1
#         again?!  ---->     1
#              4.  ---->     1
#     legacywhile  ---->     1
#            car,  ---->     1
#          house,  ---->     1
#            job,  ---->     1
#          corner  ---->     1
#         office;  ---->     1
#         leaving  ---->     1
#          legacy  ---->     1
#          world.  ---->     1
#      empowering  ---->     1
#        maximize  ---->     1
#       potential  ---->     1
#         fulfill  ---->     1
#        purpose.  ---->     1
#       inspiring  ---->     1
#            look  ---->     1
#          beyond  ---->     1
#      themselves  ---->     1
#         service  ---->     1
#         others.  ---->     1
#              5.  ---->     1
#   mistakes……and  ---->     1
#            them  ---->     1
#           well!  ---->     1
#        journey.  ---->     1
#          ensure  ---->     1
#          again.  ---->     1
#              6.  ---->     1
#   vulnerablethe  ---->     1
#              no  ---->     1
#            debt  ---->     1
#   relationships  ---->     1
#  vulnerability.  ---->     1
#        although  ---->     1
#     emotionally  ---->     1
#         strong,  ---->     1
#         willing  ---->     1
#             cry  ---->     1
#           these  ---->     1
#        emotions  ---->     1
#       essential  ---->     1
#              7.  ---->     1
#       mindwhile  ---->     1
#        everyone  ---->     1
#            else  ---->     1
#             too  ---->     1
#             may  ---->     1
#            say,  ---->     1
#           mind.  ---->     1
#           value  ---->     1
#           comes  ---->     1
#         within,  ---->     1
#             say  ---->     1
#            her.  ---->     1
#              8.  ---->     1
#        quietshe  ---->     1
#              by  ---->     1
#             abe  ---->     1
#       lincoln’s  ---->     1
#          words,  ---->     1
#         “better  ---->     1
#          silent  ---->     1
#         thought  ---->     1
#           fool,  ---->     1
#            than  ---->     1
#          remove  ---->     1
#         doubt.”  ---->     1
#              9.  ---->     1
#            have  ---->     1
#      funwhether  ---->     1
#        symphony  ---->     1
#            ball  ---->     1
#           game,  ---->     1
#            made  ---->     1
#              up  ---->     1
#     experiences  ---->     1
#               –  ---->     1
#          places  ---->     1
#             go.  ---->     1
#            able  ---->     1
#          moment  ---->     1
#           enjoy  ---->     1
#           fully  ---->     1
#           being  ---->     1
#         future.  ---->     1
#           after  ---->     1
#            all,  ---->     1
#           who’s  ---->     1
#             got  ---->     1
#      guaranteed  ---->     1
#         future?  ---->     1
#             10.  ---->     1
#     changewhile  ---->     1
#          rather  ---->     1
#        continue  ---->     1
#          living  ---->     1
#     unfulfilled  ---->     1
#            long  ---->     1
#         comfort  ---->     1
#            zone  ---->     1
#         remains  ---->     1
#         intact,  ---->     1
#       embracing  ---->     1
#          growth  ---->     1
#          cannot  ---->     1
#            gift  ---->     1
#          offers  ---->     1
#          choose  ---->     1
#        destiny.  ---->     1
#      therefore,  ---->     1
#           stone  ---->     1
#         towards  ---->     1
#        success.  ---->     1
